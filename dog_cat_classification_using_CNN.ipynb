# %% [markdown]
# <a href="https://colab.research.google.com/github/MorningStarTM/Machine_Learning_Examples/blob/main/dog_cat_classification_using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries and extract dataset
from zipfile import ZipFile

with ZipFile("/content/drive/MyDrive/archive - 2022-09-04T142141.405.zip") as imgZip:
  imgZip.extractall("/content/drive/MyDrive/dog and cat/train")

# %%
#view sample image
import matplotlib.pyplot as plt
img_path = "/content/drive/MyDrive/dog and cat/train/training_set/training_set/cats/cat.1.jpg"
img = plt.imread(img_path)
plt.imshow(img)
